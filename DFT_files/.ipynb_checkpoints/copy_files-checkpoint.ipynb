# %%
import numpy as np
import scipy as sci
import os
import pandas as pd
import shutil
import copy

# %%
df_rxns = pd.read_csv('DFT_paths_gly_ox_March2024_local.csv')
df_rxns
# Out:
#      Unnamed: 0                                   Calc  \
# 0           NaN                            formate ion
# 1           NaN                            oxalate ion
# 2           NaN                                     O2
# 3           NaN                              hydronium
# 4           NaN                                  water
# ..          ...                                    ...
# 62          NaN           TS_glyoxylic acid rad O2 add
# 63          NaN       TS_glyoxylate hydrate rad O2 add
# 64  placeholder  TS_O2 add to dihydroxy methyl radical
# 65          NaN           TS_O2 add to formic acid rad
# 66  placeholder         TS_O2- add glyoxal monohydrate
#
#                                                Smiles  \
# 0                                      [CH]([O-])=[O]
# 1                          [O-][C](=[O])[C](=[O])[O-]
# 2                                              [O][O]
# 3                                              [OH3+]
# ...

# %%
for i in range(len(df_rxns)):
    path_geom = df_rxns['path_l_geom'][i]
    path_freq = df_rxns['path_l_freq'][i]
# Out:
# /Users/arifischer/Documents/NTU_research/QChem/glyoxal/C1_radical_reactions/formate/freq
# /Users/arifischer/Documents/NTU_research/QChem/glyoxal/oxalic_acid_frag/oxalate/freq
# /Users/arifischer/Documents/NTU_research/QChem/benzyl_alcohol/fragmentation/OOH_reactions/geom_compile/O2/freq
# /Users/arifischer/Documents/NTU_research/QChem/benzyl_alcohol/fragmentation/Glyoxylic_acid_OH_ox_4May/hydronium/freq
# /Users/arifischer/Documents/NTU_research/QChem/benzyl_alcohol/fragmentation/general/H2O/SMD/freq
# /Users/arifischer/Documents/NTU_research/QChem/benzyl_alcohol/fragmentation/OOH_reactions/geom_compile/H2O2/freq
# /Users/arifischer/Documents/NTU_research/QChem/benzyl_alcohol/fragmentation/OOH_reactions/geom_compile/OOH/freq
# /Users/arifischer/Documents/NTU_research/QChem/glyoxal/C1_radical_reactions/CO2/freq
# /Users/arifischer/Documents/NTU_research/QChem/benzyl_alcohol/fragmentation/glyoxal_ROO_reactions/formic_acid/freq
# ...
